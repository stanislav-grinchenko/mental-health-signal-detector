# %% [markdown]
# ## Data Collections

# %%
# TODO: Download Dataset from kaggle and save it in the data folder.
import subprocess
import sys

try:
    import kagglehub
except ModuleNotFoundError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "kagglehub"])
    import kagglehub

# Download latest version
path = kagglehub.dataset_download("infamouscoder/depression-reddit-cleaned")
print("Path to dataset files:", path)
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Using cached kagglesdk-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (6.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aea/.pyenv/versions/Artefact/lib/python3.11/site-packages (from requests->kagglehub) (2026.2.25)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Using cached kagglesdk-0.1.16-py3-none-any.whl (160 kB)
# Installing collected packages: kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.16
# Downloading to /home/aea/.cache/kagglehub/datasets/infamouscoder/depression-reddit-cleaned/1.archive...
# 100%|██████████| 979k/979k [00:00<00:00, 1.79MB/s]
# Extracting files...
# Path to dataset files: /home/aea/.cache/kagglehub/datasets/infamouscoder/depression-reddit-cleaned/versions/1
